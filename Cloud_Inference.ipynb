# %% [markdown]
# # Football AI Commentary - Cloud Inference
# Notebook này được thiết lập sẵn để chạy hệ thống **Football AI Commentary (tích hợp Llama-3)** trên **Google Colab** hoặc **Kaggle** sử dụng GPU miễn phí.

# %% [markdown]
# ### 1. Chuẩn bị mã nguồn và Video
# Trước khi chạy các ô code bên dưới, hãy đảm bảo bạn đã:
# - Upload toàn bộ thư mục code (dạng file `.zip` sau đó giải nén, hoặc clone từ Github) lên không gian làm việc của Colab/Kaggle.
# - Upload file video gốc (ví dụ: `sample.mp4`) lên.

# %%
import os
# Đổi thư mục làm việc hiện tại vào thư mục gốc của dự án
# THAY ĐỔI ĐƯỜNG DẪN NÀY CHO PHÙ HỢP VỚI NƠI BẠN LƯU CODE
project_path = "/content/football-commentary-system" # Dành cho Colab
# project_path = "/kaggle/working/football-commentary-system" # Dành cho Kaggle

if os.path.exists(project_path):
    os.chdir(project_path)
print("Thư mục làm việc hiện tại:", os.getcwd())

# %% [markdown]
# ### 2. Cài đặt các thư viện cần thiết

# %%
# !pip install ultralytics gtts transformers accelerate bitsandbytes huggingface_hub

# %% [markdown]
# ### 3. Đăng nhập HuggingFace để tải Llama-3
# Truy cập `https://huggingface.co/settings/tokens` để lấy token của bạn và dán vào bên dưới.

# %%
from huggingface_hub import login

hf_token = "YOUR_HF_TOKEN_HERE" # <-- THAY TOKEN CỦA BẠN VÀO ĐÂY
login(token=hf_token)

# %% [markdown]
# ### 4. Chạy Analytics Pipeline
# Tiến hành chạy mô hình. Thay đổi `video_path` trỏ tới file video bạn muốn phân tích.

# %%
import os

# Thiết lập PYTHONPATH để nhận diện thư mục src
os.environ['PYTHONPATH'] = "src"

# Đường dẫn video đầu vào
video_path = "data/raw/sample.mp4"

# Chạy lệnh CLI với thiết bị GPU (cuda)
# !python src/football_ai/cli.py --mode analytics --input "{video_path}" --device cuda

# %% [markdown]
# ### 5. Xem hoặc Tải kết quả
# File video kết quả sẽ nằm tại `data/outputs/demo/analytics_video_with_audio.mp4`
