# %% [markdown]
# # Train Soccer Player Detector on Kaggle
#
# Output chính sau khi train sẽ được copy ra:
#
# ```text
# /kaggle/working/exported_models/football-player-detection.pt
# ```

# %%
# !nvidia-smi || echo "Không thấy GPU. Hãy bật Accelerator = GPU trong Kaggle Settings."
# Out:
# Fri May 15 00:47:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 2. Thiết lập môi trường Kaggle

# %%
import os
from pathlib import Path

HOME = "/kaggle/working"
DATASETS_DIR = f"{HOME}/datasets"
EXPORT_DIR = f"{HOME}/exported_models"

os.makedirs(DATASETS_DIR, exist_ok=True)
os.makedirs(EXPORT_DIR, exist_ok=True)

# Tắt WandB để YOLO không hỏi login trong lúc train.
os.environ["WANDB_DISABLED"] = "true"
os.environ["YOLO_CONFIG_DIR"] = f"{HOME}/.config/Ultralytics"

print("HOME:", HOME)
print("DATASETS_DIR:", DATASETS_DIR)
print("EXPORT_DIR:", EXPORT_DIR)
# Out:
# HOME: /kaggle/working
# DATASETS_DIR: /kaggle/working/datasets
# EXPORT_DIR: /kaggle/working/exported_models

# %% [markdown]
# ## 3. Cài dependency

# %%
# !pip install -q --upgrade ultralytics roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 36.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 56.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 92.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2026.2.0 which is incompatible.

# %% [markdown]
# ## 4. Import thư viện và lấy Roboflow API key từ Kaggle Secrets

# %%
import os
import shutil
import yaml
from pathlib import Path
from IPython.display import Image, display

from roboflow import Roboflow

try:
    from kaggle_secrets import UserSecretsClient
    ROBOFLOW_API_KEY = UserSecretsClient().get_secret("ROBOFLOW_API_KEY")
except Exception as e:
    ROBOFLOW_API_KEY = os.environ.get("ROBOFLOW_API_KEY")

if not ROBOFLOW_API_KEY:
    raise RuntimeError(
        "Thiếu ROBOFLOW_API_KEY. Trên Kaggle hãy vào Add-ons → Secrets "
        "và thêm secret tên ROBOFLOW_API_KEY."
    )

print("Đã đọc Roboflow API key.")
# Out:
# Đã đọc Roboflow API key.

# %% [markdown]
# ## 5. Tải dataset từ Roboflow

# %%
# %cd {DATASETS_DIR}

rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(10)
dataset = version.download("yolov8")

print("Dataset location:", dataset.location)
# Out:
# /kaggle/working/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-10 to yolov8:: 100%|██████████| 70212/70212 [00:00<00:00, 77596.86it/s]
# Extracting Dataset Version Zip to football-players-detection-10 in yolov8:: 100%|██████████| 636/636 [00:00<00:00, 3389.96it/s]
# WARNING ⚠️ user config directory '/kaggle/working/.config/Ultralytics/Ultralytics' is not writable, using '/tmp/Ultralytics'. Set YOLO_CONFIG_DIR to override.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/tmp/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Dataset location: /kaggle/working/datasets/football-players-detection-10

# %% [markdown]
# ## 6. Sửa `data.yaml` cho đúng format đường dẫn của Ultralytics

# %%
data_yaml = Path(dataset.location) / "data.yaml"

with open(data_yaml, "r") as f:
    data = yaml.safe_load(f)

# Roboflow thường tạo thư mục train/valid/test cùng cấp với data.yaml.
# Các đường dẫn tương đối dưới đây phù hợp với Ultralytics khi chạy trên Kaggle.
data["train"] = "../train/images"
data["val"] = "../valid/images"

test_images = Path(dataset.location).parent / "test" / "images"
if test_images.exists():
    data["test"] = "../test/images"

with open(data_yaml, "w") as f:
    yaml.safe_dump(data, f, sort_keys=False)

print(data_yaml)
print(data)
# Out:
# /kaggle/working/datasets/football-players-detection-10/data.yaml
# {'names': ['ball', 'goalkeeper', 'player', 'referee'], 'nc': 4, 'roboflow': {'license': 'CC BY 4.0', 'project': 'football-players-detection-3zvbc', 'url': 'https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/dataset/10', 'version': 10, 'workspace': 'roboflow-jvuqo'}, 'test': '../test/images', 'train': '../train/images', 'val': '../valid/images'}

# %% [markdown]
# ## 7. Train model

# %%
# %cd {HOME}

TASK = "detect"
MODEL = "yolov8x.pt"
EPOCHS = 50
IMGSZ = 1280
BATCH = -1
DEVICE = 0
RUN_NAME = "football_player_detector_kaggle"
RUN_DIR = f"{HOME}/runs/detect/{RUN_NAME}"

# Original notebook dùng batch=6. Trên Kaggle nên để -1 để YOLO tự chọn batch phù hợp GPU.
print("Training config:")
print("TASK:", TASK)
print("MODEL:", MODEL)
print("EPOCHS:", EPOCHS)
print("IMGSZ:", IMGSZ)
print("BATCH:", BATCH)
print("RUN_DIR:", RUN_DIR)
# Out:
# /kaggle/working
# Training config:
# TASK: detect
# MODEL: yolov8x.pt
# EPOCHS: 50
# IMGSZ: 1280
# BATCH: -1
# RUN_DIR: /kaggle/working/runs/detect/football_player_detector_kaggle

# %%
# !yolo task={TASK} mode=train \
    model={MODEL} \
    data={dataset.location}/data.yaml \
    batch={BATCH} \
    epochs={EPOCHS} \
    imgsz={IMGSZ} \
    device={DEVICE} \
    project={HOME}/runs/detect \
    name={RUN_NAME} \
    exist_ok=True \
    plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8x.pt to 'yolov8x.pt': 100% ━━━━━━━━━━━━ 130.5MB 151.7MB/s 0.9s
# Ultralytics 8.4.50 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/datasets/football-players-detection-10/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8x.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=football_player_detector_kaggle, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/football_player_detector_kaggle, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/tmp/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8721820  ultralytics.nn.modules.head.Detect           [4, 16, None, [320, 640, 640]]
# Model summary: 210 layers, 68,156,460 parameters, 68,156,444 gradients, 258.1 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 64.5MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2862.8±1124.6 MB/s, size: 221.1 KB)
# train: Scanning /kaggle/working/datasets/football-players-detection-10/train/labels... 250 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 250/250 1.0Kit/s 0.2s
# train: New cache created: /kaggle/working/datasets/football-players-detection-10/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# AutoBatch: Computing optimal batch size for imgsz=1280 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (Tesla T4) 14.56G total, 0.60G reserved, 0.55G allocated, 13.41G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     68156460        1033         7.598         166.3           nan      (1, 3, 1280, 1280)                    list
#     68156460        2065        16.519           192           nan      (2, 3, 1280, 1280)                    list
# CUDA out of memory. Tried to allocate 32.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 5.81 MiB is free. Including non-PyTorch memory, this process has 14.55 GiB memory in use. Of the allocated memory 14.21 GiB is allocated by PyTorch, and 191.95 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# CUDA out of memory. Tried to allocate 64.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 29.81 MiB is free. Including non-PyTorch memory, this process has 14.53 GiB memory in use. Of the allocated memory 13.98 GiB is allocated by PyTorch, and 404.63 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# CUDA out of memory. Tried to allocate 250.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 45.81 MiB is free. Including non-PyTorch memory, this process has 14.52 GiB memory in use. Of the allocated memory 14.02 GiB is allocated by PyTorch, and 343.60 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/autobatch.py:112: RankWarning: Polyfit may be poorly conditioned
#   p = np.polyfit(fit_x, fit_y, deg=1)  # first-degree polynomial fit in log space
# AutoBatch: Using batch-size 1 for CUDA:0 8.75G/14.56G (60%) ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1876.7±438.1 MB/s, size: 226.0 KB)
# train: Scanning /kaggle/working/datasets/football-players-detection-10/train/labels.cache... 250 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 250/250 74.9Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1308.8±1018.1 MB/s, size: 215.3 KB)
# val: Scanning /kaggle/working/datasets/football-players-detection-10/valid/labels... 43 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 43/43 910.1it/s 0.0s
# val: New cache created: /kaggle/working/datasets/football-players-detection-10/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/football_player_detector_kaggle/labels.jpg...
# Image sizes 1280 train, 1280 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/football_player_detector_kaggle
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.06G     0.8793     0.9229     0.8473         25       1280: 100% ━━━━━━━━━━━━ 250/250 2.9it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 4.8it/s 4.6s
#                    all         43       1025      0.658      0.754      0.778       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      4.06G     0.8902     0.8648     0.8577         32       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.1it/s 3.6s
#                    all         43       1025      0.662      0.714      0.664      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      4.06G     0.9745     0.8788     0.8701         23       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.671       0.65      0.648      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      4.06G      1.019     0.8058      0.881         55       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.748      0.678      0.696      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      4.06G     0.9623     0.7069     0.8643         48       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.1it/s 3.6s
#                    all         43       1025      0.795      0.768      0.775      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      4.06G     0.9299     0.5988     0.8641         34       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.849      0.817      0.835      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      4.06G     0.8704     0.5706     0.8491         19       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.815      0.771      0.832      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      4.06G     0.8801     0.5687     0.8457         98       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.892      0.761      0.826      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      4.06G     0.8623     0.5274     0.8454         22       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.772       0.77      0.829      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      4.11G     0.8698     0.5088     0.8424         70       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.836      0.809      0.844      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      4.11G     0.8347     0.4856     0.8445         19       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.1it/s 3.6s
#                    all         43       1025      0.849      0.749        0.8      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      4.11G     0.8875     0.4876     0.8474         43       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.898      0.814       0.85      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      4.11G     0.8787     0.4611     0.8433         22       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.904      0.805      0.856      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      4.11G     0.8542     0.4601     0.8485         47       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.912      0.835      0.856      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      4.11G     0.7837      0.417     0.8357         18       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.902      0.819      0.867      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      4.11G     0.8011     0.4227     0.8248         45       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.931        0.8      0.868      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      4.11G     0.7586     0.4021     0.8264         15       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.906       0.84      0.871      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      4.11G      0.773     0.4018      0.828         85       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.938      0.802      0.878      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      4.11G     0.7344     0.3852     0.8272         24       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.912      0.849      0.868      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      4.11G     0.7399     0.3873     0.8222         60       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.3it/s 3.5s
#                    all         43       1025      0.909      0.856      0.885      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      4.11G     0.7047     0.3716     0.8143         92       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.937      0.838      0.878      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      4.11G     0.7102     0.3727     0.8197         70       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.924      0.814      0.864      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      4.11G     0.6956     0.3644     0.8131         50       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.899       0.85      0.873      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      4.11G      0.702     0.3714     0.8149         18       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.911      0.828      0.888      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      4.11G     0.7004     0.3674     0.8194         31       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.896       0.84      0.877      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      4.11G     0.7427     0.3695     0.8189         37       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.891       0.84      0.869       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      4.11G     0.7078     0.3685     0.8188         32       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.896      0.839      0.869      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      4.11G     0.7014     0.3671     0.8199         20       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.897       0.85      0.877      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      4.11G     0.6902      0.348     0.8153         23       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025       0.88      0.855      0.866      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      4.11G     0.6914     0.3476     0.8116         40       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.938      0.814      0.881      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      4.11G     0.6634     0.3287      0.811         20       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.888       0.87      0.893      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      4.11G     0.6827     0.3442     0.8096         56       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.936      0.825      0.871      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      4.11G     0.6655     0.3364     0.8097         17       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.947      0.847      0.883      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      4.11G     0.6587      0.328     0.8076         28       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.934      0.859      0.875      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      4.11G     0.6679     0.3329     0.8057         69       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.908      0.858      0.874      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      4.11G     0.6345     0.3151     0.7993         99       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.929       0.86      0.881      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      4.11G     0.6376     0.3131     0.8055         27       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.936      0.854      0.884      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      4.11G      0.647      0.321     0.8053         81       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.946      0.864      0.885      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      4.11G     0.6371     0.3196     0.8013         29       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.924      0.859      0.884      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      4.11G     0.5982     0.3081     0.8016         42       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.888      0.871       0.88      0.657
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      4.11G     0.6207     0.3163     0.7986         25       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.905      0.851      0.872      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      4.11G     0.6233     0.3163     0.7924         24       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.959       0.85      0.873      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      4.11G     0.6258     0.3185     0.7952         21       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.943      0.847      0.871      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      4.11G     0.6229     0.3174        0.8         24       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.931       0.85      0.875      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      4.11G     0.6061     0.3151     0.7979         24       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.958      0.824      0.877      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      4.11G     0.6253     0.3162      0.797         25       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.965      0.823      0.874       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      4.11G     0.6014     0.3088     0.7947         24       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.961      0.832      0.876      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      4.11G     0.6002     0.3053     0.7894         22       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.955      0.839       0.88      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      4.11G     0.6228     0.3131     0.7957         24       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.5s
#                    all         43       1025      0.956      0.839       0.88      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      4.11G     0.5884     0.2972      0.796         22       1280: 100% ━━━━━━━━━━━━ 250/250 2.8it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.2it/s 3.6s
#                    all         43       1025      0.958      0.835       0.88      0.649
#
# 50 epochs completed in 1.314 hours.
# Optimizer stripped from /kaggle/working/runs/detect/football_player_detector_kaggle/weights/last.pt, 136.8MB
# Optimizer stripped from /kaggle/working/runs/detect/football_player_detector_kaggle/weights/best.pt, 136.8MB
#
# Validating /kaggle/working/runs/detect/football_player_detector_kaggle/weights/best.pt...
# Ultralytics 8.4.50 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 113 layers, 68,127,420 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.3it/s 3.5s
#                    all         43       1025      0.909      0.856      0.886      0.658
#                   ball         39         39      0.785      0.564      0.599      0.313
#             goalkeeper         32         32      0.965      0.906      0.966      0.799
#                 player         43        853      0.968      0.984      0.992      0.806
#                referee         43        101      0.918       0.97      0.986      0.715
# Speed: 0.9ms preprocess, 70.5ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/football_player_detector_kaggle
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# ## 8. Xem nhanh kết quả train

# %%
RUN_DIR = Path(f"{HOME}/runs/detect/{RUN_NAME}")
print("RUN_DIR:", RUN_DIR)
# !ls -lah {RUN_DIR}

for img_name in ['confusion_matrix.png', 'results.png', 'val_batch0_pred.jpg']:
    img_path = RUN_DIR / img_name
    if img_path.exists():
        print("\nPreview:", img_path)
        display(Image(filename=str(img_path), width=700))
    else:
        print("Không tìm thấy:", img_path)
# Out:
# RUN_DIR: /kaggle/working/runs/detect/football_player_detector_kaggle
# total 3.7M
# drwxr-xr-x 3 root root 4.0K May 15 02:07 .
# drwxr-xr-x 3 root root 4.0K May 15 00:48 ..
# -rw-r--r-- 1 root root 1.7K May 15 00:48 args.yaml
# -rw-r--r-- 1 root root 203K May 15 02:07 BoxF1_curve.png
# -rw-r--r-- 1 root root 149K May 15 02:07 BoxP_curve.png
# -rw-r--r-- 1 root root 121K May 15 02:07 BoxPR_curve.png
# -rw-r--r-- 1 root root 178K May 15 02:07 BoxR_curve.png
# -rw-r--r-- 1 root root 156K May 15 02:07 confusion_matrix_normalized.png
# -rw-r--r-- 1 root root 144K May 15 02:07 confusion_matrix.png
# -rw-r--r-- 1 root root 109K May 15 00:48 labels.jpg
# -rw-r--r-- 1 root root 6.1K May 15 02:07 results.csv
# -rw-r--r-- 1 root root 332K May 15 02:07 results.png
# -rw-r--r-- 1 root root 260K May 15 00:48 train_batch0.jpg
# -rw-r--r-- 1 root root 142K May 15 01:51 train_batch10000.jpg
# -rw-r--r-- 1 root root 144K May 15 01:51 train_batch10001.jpg
# -rw-r--r-- 1 root root 133K May 15 01:51 train_batch10002.jpg
# -rw-r--r-- 1 root root 167K May 15 00:48 train_batch1.jpg
# -rw-r--r-- 1 root root 181K May 15 00:48 train_batch2.jpg
# -rw-r--r-- 1 root root 206K May 15 02:07 val_batch0_labels.jpg
# -rw-r--r-- 1 root root 216K May 15 02:07 val_batch0_pred.jpg
# -rw-r--r-- 1 root root 199K May 15 02:07 val_batch1_labels.jpg
# -rw-r--r-- 1 root root 210K May 15 02:07 val_batch1_pred.jpg
# -rw-r--r-- 1 root root 191K May 15 02:07 val_batch2_labels.jpg
# -rw-r--r-- 1 root root 201K May 15 02:07 val_batch2_pred.jpg
# drwxr-xr-x 2 root root 4.0K May 15 00:50 weights
#
# Preview: /kaggle/working/runs/detect/football_player_detector_kaggle/confusion_matrix.png
# Preview: /kaggle/working/runs/detect/football_player_detector_kaggle/results.png
# Preview: /kaggle/working/runs/detect/football_player_detector_kaggle/val_batch0_pred.jpg

# %% [markdown]
# ## 9. Validate model tốt nhất

# %%
BEST_PT = Path(RUN_DIR) / "weights" / "best.pt"
print("BEST_PT:", BEST_PT)

# !yolo task={TASK} mode=val \
    model={BEST_PT} \
    data={dataset.location}/data.yaml \
    imgsz={IMGSZ} \
    device={DEVICE}
# Out:
# BEST_PT: /kaggle/working/runs/detect/football_player_detector_kaggle/weights/best.pt
# Ultralytics 8.4.50 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 113 layers, 68,127,420 parameters, 0 gradients, 257.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3290.8±607.0 MB/s, size: 219.9 KB)
# val: Scanning /kaggle/working/datasets/football-players-detection-10/valid/labels.cache... 43 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 43/43 8.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.0s/it 9.0s
#                    all         43       1025      0.916      0.856      0.884      0.668
#                   ball         39         39      0.814      0.564      0.601      0.321
#             goalkeeper         32         32      0.965      0.906      0.966      0.805
#                 player         43        853      0.968      0.982      0.984      0.817
#                referee         43        101      0.918       0.97      0.986       0.73
# Speed: 10.4ms preprocess, 175.3ms inference, 0.0ms loss, 5.4ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## 10. Copy model ra thư mục export để tải về

# %%
EXPORT_PATH = Path(EXPORT_DIR) / "football-player-detection.pt"
shutil.copy2(BEST_PT, EXPORT_PATH)

print("Đã copy model sang:")
print(EXPORT_PATH)
print("Dung lượng MB:", round(EXPORT_PATH.stat().st_size / (1024 * 1024), 2))
# Out:
# Đã copy model sang:
# /kaggle/working/exported_models/football-player-detection.pt
# Dung lượng MB: 130.45

# %% [markdown]
# ## 11. Nén toàn bộ kết quả train để tải về từ Kaggle Output

# %%
ZIP_PATH = f"{HOME}/train_player_detector_kaggle_outputs.zip"

# !cd {HOME} && zip -qr train_player_detector_kaggle_outputs.zip runs/detect/football_player_detector_kaggle exported_models/football-player-detection.pt

print("ZIP output:", ZIP_PATH)
# Out:
# ZIP output: /kaggle/working/train_player_detector_kaggle_outputs.zip
